# %% [markdown]
# ## Оптимизация выполнения кода, векторизация, Numba

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 3: Оптимизация выполнения кода, векторизация, Numba
# * IPython Cookbook, Second Edition (2018), глава 4
# * https://numba.pydata.org/numba-doc/latest/user/5minguide.html

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Сгенерируйте массив `A` из `N=1млн` случайных целых чисел на отрезке от 0 до 1000. Пусть `B[i] = A[i] + 100`. Посчитайте среднее значение массива `B`.

# %%
# %%time
import numpy as np
A = np.random.randint(0, 10000, 10**6)
print('A = ',A)
B = A+100
print('B = ',B)
print('Среднее значение - ', np.mean(B))
# Out:
# A =  [1508 2518  887 ... 2883 6818  512]
# B =  [1608 2618  987 ... 2983 6918  612]
# Среднее значение -  5104.758098
# CPU times: total: 422 ms
# Wall time: 540 ms

# %% [markdown]
# 2. Создайте таблицу 2млн строк и с 4 столбцами, заполненными случайными числами. Добавьте столбец `key`, которые содержит элементы из множества английских букв. Выберите из таблицы подмножество строк, для которых в столбце `key` указаны первые 5 английских букв.

# %%
# %%time
import numpy as np
vals = np.random.randint((2*10**6),size = (2*10**6,4))
alphabet = list(map(chr, range(ord('a'), ord('z')+1)))
alphabet += list(map(lambda x: x.upper(), alphabet))
first_5 = alphabet[:5]
first_5 +=list(map(lambda x: x.upper(), first_5))

a = np.random.choice(alphabet, 2*10**6)

a.shape = (2000000,1)
result = np.concatenate((a,vals ), axis=1)
res = result[np.isin(result[:, 0], first_5)]
print(res.shape[0])
# Out:
# 384591
# CPU times: total: 9.48 s
# Wall time: 9.62 s

# %% [markdown]
# ## Лабораторная работа 3

# %%
# !pip install line_profiler

# %% [markdown]
# 1. В файлах `recipes_sample.csv` и `reviews_sample.csv` (__ЛР 2__) находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца(ов) с индексами. Приведите столбцы к нужным типам.
#
# Реализуйте несколько вариантов функции подсчета среднего значения столбца `rating` из таблицы `reviews` для отзывов, оставленных в 2010 году.
#
# A. С использованием метода `DataFrame.iterrows` исходной таблицы;
#
# Б. С использованием метода `DataFrame.iterrows` таблицы, в которой сохранены только отзывы за 2010 год;
#
# В. С использованием метода `Series.mean`.
#
# Проверьте, что результаты работы всех написанных функций корректны и совпадают. Измерьте выполнения всех написанных функций.

# %%
import pandas as pd
recipes = pd.read_csv('recipes_sample.csv', parse_dates=['submitted'])
reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [30000 rows x 8 columns]

# %%
# %%time
#A. С использованием метода DataFrame.iterrows исходной таблицы;
def count_rating1():
    reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
    summ = 0
    count = 0
    for index, row in reviews.iterrows():
        if row['date'].year==2010:
            count+=1
            summ+=row['rating']
    answer1 = summ/count
    return answer1
count_rating1()
# Out:
# CPU times: total: 9.92 s
# Wall time: 10 s
# 4.4544402182900615

# %%
# %%time
#Б. С использованием метода DataFrame.iterrows таблицы, в которой сохранены только отзывы за 2010 год;
def count_rating2():
    reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
    summ = 0 
    reviews1 = reviews[reviews['date'].dt.year==2010]
    for index, row in reviews1.iterrows():
        summ+=row['rating']

    answer2 = (summ/reviews1.shape[0])
    return answer2
count_rating2()
# Out:
# CPU times: total: 2.11 s
# Wall time: 2.3 s
# 4.4544402182900615

# %%
# %%time
#В. С использованием метода Series.mean
def count_rating3():
    reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
    answer3 = reviews[reviews['date'].dt.year==2010].rating.mean()
    return answer3
count_rating3()
# Out:
# CPU times: total: 1.16 s
# Wall time: 1.2 s
# 4.4544402182900615

# %%
count_rating1()==count_rating2()==count_rating3()
# Out:
# True

# %% [markdown]
# 2. Какая из созданных функций выполняется медленнее? Что наиболее сильно влияет на скорость выполнения? Для ответа использовать профайлер `line_profiler`. Сохраните результаты работы профайлера в отдельную текстовую ячейку и прокомментируйте результаты его работы.
#
# (*). Сможете ли вы ускорить работу функции 1Б, отказавшись от использования метода `iterrows`, но не используя метод `mean`?

# %% [markdown]
# ### 1A - самая медленная функция

# %%
# !pip install line_profiler
# Out:
# Requirement already satisfied: line_profiler in c:\users\maria\anaconda3\lib\site-packages (4.0.3)

# %%
# !pip install memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in c:\users\maria\anaconda3\lib\site-packages (0.61.0)
# Requirement already satisfied: psutil in c:\users\maria\anaconda3\lib\site-packages (from memory_profiler) (5.8.0)

# %%
# %load_ext line_profiler

# %%
# %reload_ext line_profiler

# %%
# %load_ext memory_profiler

# %%
# %%writefile demo.py
def count_rating1():
    reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
    summ = 0
    count = 0
    for index, row in reviews.iterrows():
        if row['date'].year==2010:
            count+=1
            summ+=row['rating']
    answer1 = summ/count
    return answer1
# Out:
# Overwriting demo.py

# %%
import cProfile, pstats, io


def profile(fnc):
    
    """A decorator that uses cProfile to profile a function"""
    
    def inner(*args, **kwargs):
        
        pr = cProfile.Profile()
        pr.enable()
        retval = fnc(*args, **kwargs)
        pr.disable()
        s = io.StringIO()
        sortby = 'cumulative'
        ps = pstats.Stats(pr, stream=s).sort_stats(sortby)
        ps.print_stats()
        print(s.getvalue())
        return retval

    return inner
@profile
def count_rating1():
    reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
    summ = 0
    count = 0
    for index, row in reviews.iterrows():
        if row['date'].year==2010:
            count+=1
            summ+=row['rating']
    answer1 = summ/count
    return answer1

# %%
count_rating1()
# Out:
#          16361090 function calls (16107661 primitive calls) in 17.545 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.370    0.370   17.545   17.545 C:\Users\maria\AppData\Local\Temp\ipykernel_12028\1053370662.py:22(count_rating1)
#    126697    0.407    0.000   13.054    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\frame.py:1279(iterrows)
# 126702/126699    1.551    0.000   12.405    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:323(__init__)
#    126708    0.852    0.000    3.536    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:470(sanitize_array)
#    138790    0.532    0.000    2.966    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:943(__getitem__)
#    126699    0.337    0.000    2.404    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1731(from_array)
#    138790    0.337    0.000    1.942    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:1052(_get_value)
#    126699    0.518    0.000    1.782    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2041(new_block)
#    126704    0.458    0.000    1.646    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5577(__setattr__)
#    126700    0.132    0.000    1.550    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:255(__call__)
#    126700    0.204    0.000    1.419    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:127(_get_option)
#    126708    0.372    0.000    1.393    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:695(_try_cast)
# 3988940/3988938    0.904    0.000    1.190    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    1.156    1.156 C:\Users\maria\anaconda3\lib\site-packages\pandas\util\_decorators.py:302(wrapper)
#         1    0.000    0.000    1.155    1.155 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:584(read_csv)
#         1    0.003    0.003    1.155    1.155 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:539(_read)
#         1    0.000    0.000    1.143    1.143 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1244(read)
#         1    0.003    0.003    1.130    1.130 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215(read)
#         1    0.978    0.978    1.009    1.009 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#    126697    0.606    0.000    0.979    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1466(maybe_infer_to_datetimelike)
#    126700    0.335    0.000    0.899    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:109(_get_single_key)
#    138790    0.239    0.000    0.860    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3577(get_loc)
#    126705    0.258    0.000    0.778    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:640(name)
#    138790    0.226    0.000    0.745    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5646(_get_values_for_loc)
#    126713    0.117    0.000    0.663    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:379(extract_array)
#    126703    0.483    0.000    0.619    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:239(__init__)
# 1520524/1267106    0.417    0.000    0.541    0.000 {built-in method builtins.len}
#    126705    0.149    0.000    0.520    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1721(validate_all_hashable)
#    138796    0.138    0.000    0.488    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:687(_values)
#    126700    0.266    0.000    0.483    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1960(maybe_coerce_values)
#    126706    0.237    0.000    0.410    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:590(name)
#    138790    0.185    0.000    0.402    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6284(_maybe_cast_indexer)
#    126699    0.231    0.000    0.395    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2055(check_ndim)
#    126717    0.130    0.000    0.371    0.000 {built-in method builtins.all}
#    126704    0.274    0.000    0.358    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1989(get_block_type)
#    138796    0.294    0.000    0.350    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1848(internal_values)
#    126700    0.242    0.000    0.316    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:589(_get_root)
#    126708    0.167    0.000    0.308    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:627(_sanitize_ndim)
#    380294    0.213    0.000    0.286    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\generic.py:43(_check)
#    126704    0.094    0.000    0.281    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\common.py:552(require_length_match)
#    138790    0.178    0.000    0.276    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexing.py:2481(check_deprecated_indexers)
#    126700    0.100    0.000    0.276    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:642(_warn_if_deprecated)
#    253400    0.271    0.000    0.271    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:603(_get_deprecated_option)
#         1    0.000    0.000    0.244    0.244 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\frame.py:10808(values)
#         1    0.003    0.003    0.244    0.244 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1541(as_array)
#    253410    0.132    0.000    0.241    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1740(<genexpr>)
#         1    0.013    0.013    0.241    0.241 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1601(_interleave)
#    126703    0.140    0.000    0.228    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:802(is_empty_data)
#    126697    0.220    0.000    0.220    0.000 {pandas._libs.lib.infer_datetimelike_array}
#    138790    0.219    0.000    0.219    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#    253419    0.150    0.000    0.213    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:321(is_hashable)
#         1    0.000    0.000    0.212    0.212 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1461(get_values)
#         1    0.000    0.000    0.212    0.212 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:645(astype)
#         1    0.000    0.000    0.212    0.212 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:403(astype)
#         1    0.212    0.212    0.212    0.212 {pandas._libs.tslibs.vectorized.ints_to_pydatetime}
#    126711    0.104    0.000    0.208    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7082(maybe_extract_name)
#    126700    0.081    0.000    0.176    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:630(_translate_key)
#    126702    0.172    0.000    0.172    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5561(__getattr__)
#    253416    0.125    0.000    0.167    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:884(__len__)
#    126709    0.125    0.000    0.143    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:438(ensure_wrapped_if_datetimelike)
#    126703    0.135    0.000    0.135    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\flags.py:47(__init__)
#    126708    0.097    0.000    0.129    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:664(_sanitize_str_dtypes)
#    138790    0.092    0.000    0.128    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\common.py:160(cast_scalar_indexer)
#    126700    0.116    0.000    0.116    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1700(__init__)
#    138790    0.077    0.000    0.111    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\common.py:346(apply_if_callable)
#         1    0.000    0.000    0.111    0.111 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:812(_do_date_conversions)
#         1    0.000    0.000    0.111    0.111 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1154(_process_date_conversion)
#    507074    0.111    0.000    0.111    0.000 {built-in method builtins.getattr}
#         1    0.008    0.008    0.110    0.110 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1065(converter)
#    380120    0.109    0.000    0.109    0.000 {pandas._libs.lib.is_list_like}
#    126708    0.084    0.000    0.104    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:684(_maybe_repeat)
#    126701    0.103    0.000    0.103    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:542(_set_axis)
#         1    0.000    0.000    0.099    0.099 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:678(to_datetime)
#         1    0.000    0.000    0.098    0.098 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:289(_convert_listlike_datetimes)
#         1    0.000    0.000    0.098    0.098 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2151(objects_to_datetime64ns)
#         1    0.098    0.098    0.098    0.098 {built-in method pandas._libs.tslib.array_to_datetime}
#    126707    0.071    0.000    0.091    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6987(ensure_index)
#    126704    0.063    0.000    0.090    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1416(is_1d_only_ea_dtype)
#    138790    0.089    0.000    0.089    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2344(is_floating)
#    126703    0.083    0.000    0.083    0.000 {built-in method numpy.array}
#    126700    0.074    0.000    0.074    0.000 {method 'split' of 'str' objects}
#    126700    0.072    0.000    0.072    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\_config\config.py:571(_select_options)
#    277583    0.066    0.000    0.066    0.000 {pandas._libs.lib.is_integer}
#    253419    0.063    0.000    0.063    0.000 {built-in method builtins.hash}
#    253522    0.061    0.000    0.061    0.000 {built-in method builtins.issubclass}
#    126699    0.056    0.000    0.056    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1792(_block)
#    126762    0.047    0.000    0.047    0.000 {built-in method builtins.hasattr}
#    253412    0.047    0.000    0.047    0.000 C:\Users\maria\anaconda3\lib\typing.py:1375(cast)
#    138800    0.037    0.000    0.037    0.000 {pandas._libs.lib.is_scalar}
#    138790    0.036    0.000    0.036    0.000 {pandas._libs.lib.is_float}
#    138791    0.034    0.000    0.034    0.000 {built-in method builtins.callable}
#    126703    0.033    0.000    0.033    0.000 {pandas._libs.algos.ensure_object}
#       278    0.001    0.000    0.031    0.000 C:\Users\maria\anaconda3\lib\codecs.py:319(decode)
#       278    0.030    0.000    0.030    0.000 {built-in method _codecs.utf_8_decode}
#         9    0.012    0.001    0.012    0.001 {method 'astype' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.012    0.006 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:222(get_values)
#         1    0.000    0.000    0.012    0.012 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\frame.py:587(__init__)
#         1    0.000    0.000    0.012    0.012 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\construction.py:425(dict_to_mgr)
#         1    0.000    0.000    0.010    0.010 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\construction.py:102(arrays_to_mgr)
#         1    0.000    0.000    0.009    0.009 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1937(create_block_manager_from_column_arrays)
#         1    0.000    0.000    0.007    0.007 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:886(__init__)
#         1    0.000    0.000    0.007    0.007 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1192(_make_engine)
#         1    0.005    0.005    0.006    0.006 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:45(__init__)
#     19/17    0.006    0.000    0.006    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         8    0.000    0.000    0.006    0.001 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.006    0.006 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2008(_form_blocks)
#         4    0.004    0.001    0.005    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2060(_stack_arrays)
#         1    0.000    0.000    0.005    0.005 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:344(_concatenate_chunks)
#        18    0.004    0.000    0.004    0.000 {built-in method numpy.empty}
#         1    0.000    0.000    0.004    0.004 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1683(_consolidate_inplace)
#         1    0.000    0.000    0.004    0.004 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2074(_consolidate)
#         3    0.002    0.001    0.003    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2091(_merge_blocks)
#         1    0.003    0.003    0.003    0.003 {pandas._libs.tslibs.parsing.concat_date_cols}
#         1    0.000    0.000    0.003    0.003 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:383(_make_index)
#         1    0.000    0.000    0.003    0.003 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:475(_agg_index)
#         1    0.000    0.000    0.003    0.003 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:679(_infer_types)
#         1    0.002    0.002    0.002    0.002 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\algorithms.py:448(isin)
#         1    0.000    0.000    0.002    0.002 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1289(__exit__)
#         1    0.000    0.000    0.002    0.002 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:935(close)
#         1    0.000    0.000    0.002    0.002 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:187(close)
#         1    0.002    0.002    0.002    0.002 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#         2    0.000    0.000    0.002    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:463(_init_dict)
#         1    0.000    0.000    0.002    0.002 <__array_function__ internals>:2(vstack)
#         1    0.000    0.000    0.002    0.002 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\shape_base.py:222(vstack)
#         4    0.000    0.000    0.001    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:672(_with_infer)
#         2    0.000    0.000    0.001    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\construction.py:822(create_series_with_explicit_dtype)
#       9/5    0.000    0.000    0.001    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:397(__new__)
#         1    0.000    0.000    0.001    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:162(_maybe_cache)
#         1    0.000    0.000    0.001    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:4655(reindex)
#         1    0.000    0.000    0.001    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:4719(reindex)
#         1    0.000    0.000    0.001    0.001 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:604(get_handle)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:4970(_reindex_axes)
#       278    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\codecs.py:331(getstate)
#         8    0.000    0.000    0.000    0.000 {pandas._libs.lib.maybe_convert_objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:341(_from_sequence_not_strict)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7106(_maybe_cast_data_without_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1994(_sequence_to_dt64ns)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4109(reindex)
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         2    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_methods.py:46(_sum)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:205(_box_as_indexlike)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py:305(__new__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3706(get_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5009(_reindex_with_indexers)
#        57    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1587(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:254(_get_filepath_or_buffer)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:5276(isna)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\base.py:210(interleaved_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:7228(isna)
#        27    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:286(is_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1789(find_common_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:337(_from_sequence)
#        19    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:497(is_categorical_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:10873(any)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:10451(any)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2243(maybe_convert_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:66(isna)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:10393(_logical_func)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:149(_isna)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\construction.py:596(_homogenize)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6947(ensure_index_from_sequences)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:103(close)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:4435(_reduce)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:599(find_common_type)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_asarray.py:22(require)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:634(reindex_indexer)
#         8    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2079(<lambda>)
#        16    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1429(is_extension_array_dtype)
#         8    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numeric.py:289(full)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:166(_consolidate_key)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:575(_can_coerce_all)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\warnings.py:130(filterwarnings)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:713(_slice_take_blocks_ax0)
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#         7    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_dtype.py:321(_name_get)
#         8    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\common.py:229(asarray_tuplesafe)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:83(__init__)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:360(<setcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2596(inferred_type)
#        10    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:680(is_integer_dtype)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:554(_dtype_to_subclass)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        16    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1240(is_float_dtype)
#        19    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:161(is_object_dtype)
#        11    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1274(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:102(should_cache)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:423(is_period_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\nanops.py:488(nanany)
#        13    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1747(pandas_dtype)
#        25    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5178(equals)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6004(_should_compare)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1018(_clean_options)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:176(_validate_parse_dates_presence)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\base.py:53(shape)
#         1    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:955(is_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5517(__finalize__)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:262(is_dict_like)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2603(_is_all_dates)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2272(is_boolean)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:130(is_url)
#         7    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:315(is_datetime64_dtype)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1960(construct_1d_object_array_from_listlike)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:940(_get_options_with_defaults)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1114(take_nd)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:1112(_is_binary_mode)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1665(is_consolidated)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\urllib\parse.py:372(urlparse)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\base.py:430(to_numpy)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:654(_simple_new)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1673(_consolidate_check)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5646(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:340(_maybe_dedup_names)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:441(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:194(_set_noconvert_columns)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:4952(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1289(_is_potential_multi_index)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:198(stringify_path)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5632(_protect_consolidate)
#        11    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\abc.py:117(__instancecheck__)
#         7    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_dtype.py:307(_name_includes_bit_suffix)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:57(take_nd)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\nanops.py:257(_get_values)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\warnings.py:181(_add_filter)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\re.py:250(compile)
#        11    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\base.py:55(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\base.py:744(__iter__)
#        20    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:155(<lambda>)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5905(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1679(<listcomp>)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:581(is_dtype_equal)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argsort)
#        18    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1483(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:120(_take_nd_ndarray)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2030(new_block_2d)
#        33    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:584(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5265(identical)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2232(is_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3786(_get_indexer)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\re.py:289(_compile)
#        37    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:147(<lambda>)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1835(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:32(seterr)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:845(_engine)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:158(_expand_user)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:238(fill_value)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:500(infer_compression)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1006(argsort)
#        27    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1552(get_dtype)
#        11    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3823(_check_indexing_method)
#        83    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:348(is_datetime64tz_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:429(__enter__)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\warnings.py:458(__enter__)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:358(issubdtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:610(_set_noconvert_dtype_columns)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_asarray.py:111(<setcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:191(is_sparse)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:226(_isna_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:571(na_value_for_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:786(is_unsigned_integer_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:326(_simple_new)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:139(_ensure_array)
#        17    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:288(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:465(get_compression_method)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:5650(f)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\common.py:287(maybe_iterable_to_list)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:371(_maybe_make_multi_index_columns)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:732(is_signed_integer_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\ntpath.py:289(expanduser)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_methods.py:54(_any)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\urllib\parse.py:437(urlsplit)
#        37    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:145(classes)
#         1    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:267(_isna_string_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2119(extend_blocks)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1992(_grouping_func)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1428(_refine_defaults_read)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\types.py:171(__get__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\typing.py:719(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:411(_get_simple_index)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1615(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:459(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:358(<setcomp>)
#        32    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:486(validate_integer)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:356(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:1911(maybe_infer_freq)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:612(__array__)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:540(is_string_dtype)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:465(find)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:280(asi8)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:354(dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\base.py:545(empty)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:284(issubclass_)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1828(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:150(classes_and_not_datetimelike)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1148(needs_i8_conversion)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:925(is_datetime64_ns_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1318(_validate_parse_dates_arg)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:743(__len__)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\warnings.py:437(__init__)
#        34    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4820(_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1007(_check_file_or_buffer)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\base.py:358(size)
#         5    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:969(_clean_index_names)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\typing.py:848(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:242(is_fsspec_url)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\warnings.py:477(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:1206(is_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:434(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5917(_maybe_promote)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:834(_reset_identity)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:131(geterr)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:98(is_file_like)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2624(_is_multi)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_dtype.py:178(_datetime_metadata_str)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\util\_decorators.py:214(_format_argument_list)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4846(_get_engine_target)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:244(mgr_locs)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:240(_has_complex_date_col)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1314(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\shape_base.py:81(atleast_2d)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\construction.py:494(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:390(array_equivalent)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7168(unpack_nested_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:698(<listcomp>)
#         7    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_dtype.py:24(_kind_name)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:389(is_timedelta64_dtype)
#         7    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:545(dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\codecs.py:309(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\nanops.py:213(_maybe_get_mask)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:560(_get_axis)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\base.py:45(__len__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:514(_construct_axes_from_arguments)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:570(tz)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1528(_is_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2102(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:645(_set)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\urllib\parse.py:114(_coerce_args)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#        19    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _simple_new}
#         4    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:554(_take_preprocess_indexer_and_fill_value)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:618(consolidate)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:651(<listcomp>)
#         7    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFBC327BC60}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:313(__array__)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1711(sanitize_to_nanoseconds)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\copy.py:66(copy)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:803(is_)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\flags.py:83(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\extension.py:67(fget)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\enum.py:792(value)
#         1    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\shape_base.py:218(_vhstack_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1722(from_blocks)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\missing.py:911(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:1058(_maybe_memory_map)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2137(_preprocess_slice_or_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\abc.py:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:249(_should_parse_dates)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\algorithms.py:237(_ensure_arraylike)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:468(maybe_promote)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:269(_extract_multi_indexer_columns)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1819(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        12    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:208(<genexpr>)
#         8    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\multiarray.py:1071(copyto)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1830(<genexpr>)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:546(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:267(make_block_same_class)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         8    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\util\_validators.py:218(validate_bool_kwarg)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1353(_clean_na_values)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\shape_base.py:207(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         5    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\nanops.py:346(_na_ok_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\construction.py:233(mgr_to_mgr)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\common.py:177(validate_header_arg)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:543(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\array_algos\take.py:326(_get_take_nd_function)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:408(ensure_dtype_objs)
#         5    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:229(disallow_kwargs)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:308(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         6    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7046(ensure_has_len)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:199(_ensure_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#         3    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:569(condition)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:540(_ensure_array)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:937(dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4226(_wrap_reindex_result)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:566(_get_block_manager_axis)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:220(<setcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1163(_isindex)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:205(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6293(_maybe_cast_listlike_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:350(shape)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1062(_make_date_converter)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2376(validate_tz_from_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:328(attrs)
#         4    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1340(is_index_col)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:304(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:184(is_array_like)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1704(_validate_skipfooter)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:413(ix)
#         5    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\_ufunc_config.py:425(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4092(_validate_can_reindex)
#         6    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\generic.py:349(flags)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:920(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\codecs.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:518(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2334(_validate_dt64_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1606(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:462(_clean_mapping)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:206(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\missing.py:107(clean_fill_method)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:96(tz_to_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:880(freq)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\arrays\datetimelike.py:1876(validate_inferred_freq)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:217(is_single_block)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:515(_validate_names)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:232(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\compat\numpy\function.py:49(__call__)
#         3    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\flags.py:51(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:2111(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:832(_check_data_length)
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:533(is_string_or_object_np_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\base.py:326(ndim)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:222(items)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\managers.py:919(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\urllib\parse.py:103(_noop)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:188(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:4488(_needs_reindex_multi)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\numerictypes.py:652(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\nanops.py:191(_get_fill_value)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1650(name)
#         2    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\series.py:523(_constructor)
#         1    0.000    0.000    0.000    0.000 {built-in method from_iterable}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4230(_maybe_preserve_names)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6022(_is_comparable_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\base.py:156(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 {method 'set_noconvert' of 'pandas._libs.parsers.TextReader' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\copy.py:107(_copy_immutable)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1002(_argsort_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\core\internals\base.py:150(is_consolidated)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\maria\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1286(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
# 4.4544402182900615

# %%
#блоки программы, занимающие наибольшее время - считывание файла и итерации

# %%
# %%time
#альтернативное решение 
def count_rating4():
    reviews = pd.read_csv('reviews_sample.csv',index_col = 0,  parse_dates=['date'])
    reviews1 = reviews[reviews['date'].dt.year==2010]
    summ_rating = reviews1.rating.sum()
    return summ_rating/reviews1.shape[0]
count_rating4()
# Out:
# CPU times: total: 1.19 s
# Wall time: 1.21 s
# 4.4544402182900615

# %% [markdown]
# 3. Вам предлагается воспользоваться функцией, которая собирает статистику о том, сколько отзывов содержат то или иное слово. Измерьте время выполнения этой функции. Сможете ли вы найти узкие места в коде, используя профайлер? Выпишите (словами), что в имеющемся коде реализовано неоптимально. Оптимизируйте функцию и добейтесь значительного (как минимум, на один порядок) прироста в скорости выполнения.

# %%
# @profile
def get_word_reviews_count(df):
    word_reviews = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        recipe_id, review = row['recipe_id'], row['review']
        words = review.split(' ')
        for word in words:
            if word not in word_reviews:
                word_reviews[word] = []
            word_reviews[word].append(recipe_id)
    
    word_reviews_count = {}
    for _, row in df.dropna(subset=['review']).iterrows():
        review = row['review']
        words = review.split(' ')
        for word in words:
            word_reviews_count[word] = len(word_reviews[word])
    return word_reviews_count

# %%
# %%time
get_word_reviews_count(reviews)
# Out:
# CPU times: total: 30.6 s
# Wall time: 30.8 s
# {'Last': 94,
#  'week': 804,
#  'whole': 5628,
#  'sides': 312,
#  'of': 109029,
#  'frozen': 2647,
#  'salmon': 729,
#  'fillet': 60,
#  'was': 88781,
#  'on': 34583,
#  'sale': 149,
#  'in': 61539,
#  'my': 44144,
#  'local': 561,
#  'supermarket,': 10,
#  'so': 46090,
#  'I': 285147,
#  'bought': 1369,
#  'tons': 161,
#  '(okay,': 5,
#  'only': 13965,
#  '3,': 48,
#  'but': 42513,
#  'total': 381,
#  'weight': 160,
#  'over': 9065,
#  '10': 2303,
#  'pounds).': 2,
#  '': 214145,
#  'This': 39448,
#  'recipe': 41098,
#  'is': 55075,
#  'perfect': 4398,
#  'for': 121224,
#  'fillet,': 14,
#  'even': 7878,
#  'though': 2314,
#  'it': 111175,
#  'calls': 520,
#  'steaks.': 93,
#  'cut': 6688,
#  'up': 13585,
#  'the': 266050,
#  'into': 7031,
#  'individual': 314,
#  'portions': 156,
#  'and': 217849,
#  'followed': 4859,
#  'instructions': 731,
#  'exactly.': 571,
#  "I'm": 7145,
#  'one': 15086,
#  'those': 2287,
#  'food': 2413,
#  'combining': 74,
#  'diets,': 5,
#  'left': 4690,
#  'out': 23644,
#  'white': 3425,
#  'wine': 1256,
#  'added': 21710,
#  'just': 24944,
#  'a': 166136,
#  'dash': 532,
#  'vinegar': 1272,
#  'instead': 10395,
#  '(just': 273,
#  'little': 16319,
#  'bit,': 316,
#  'not': 22907,
#  'enough': 4440,
#  'to': 131471,
#  'change': 4146,
#  'taste': 8026,
#  'dish).': 20,
#  'Super': 840,
#  'yummy,': 366,
#  'leftovers': 1497,
#  'lunch': 1593,
#  'today': 1034,
#  '(lucky': 3,
#  'me)!': 5,
#  'So': 4319,
#  'simple': 3947,
#  'tasty!': 994,
#  'used': 44849,
#  'yellow': 782,
#  'capsicum': 45,
#  'place': 2012,
#  'green': 4470,
#  'because': 11390,
#  "that's": 1563,
#  'what': 7462,
#  'had': 26362,
#  'hand.': 1416,
#  'came': 5263,
#  'together': 3268,
#  'fast.': 178,
#  'Perfect': 755,
#  'meal': 1891,
#  'if': 7326,
#  'you': 24475,
#  "don't": 6183,
#  'have': 35190,
#  'lot': 3186,
#  'time.': 4010,
#  'Easy,': 288,
#  'healthy': 1282,
#  'tasty.': 1986,
#  'Thanks': 26556,
#  'Stardustannie!': 4,
#  'Made': 12801,
#  'PAC': 1488,
#  'Fall': 737,
#  '2007.': 85,
#  'Very': 8691,
#  'nice': 8168,
#  'breakfast': 1398,
#  'HH,': 1,
#  'easy': 17222,
#  'make': 32124,
#  'yummy': 2111,
#  'with': 58374,
#  'fresh': 7670,
#  'hot': 3578,
#  'coffe.': 2,
#  'Instead': 860,
#  'toast': 449,
#  'served': 6449,
#  '#97694': 1,
#  'by': 6592,
#  'Paula': 121,
#  'G': 13,
#  'that': 36984,
#  'made': 38087,
#  'earlier': 167,
#  'turned': 6368,
#  'great.': 3686,
#  'will': 23985,
#  'be': 25032,
#  'regular': 2988,
#  'our': 6879,
#  'house': 1246,
#  '-': 12000,
#  'DH': 3796,
#  'loved': 13755,
#  'them.': 3663,
#  'These': 8371,
#  'are': 15518,
#  'favorite': 2587,
#  'holidays': 123,
#  'children': 356,
#  'We': 12585,
#  'also': 14466,
#  'use': 16905,
#  'Rolo': 6,
#  'candies': 59,
#  'kisses.': 14,
#  'Excellent': 1550,
#  'soup!': 456,
#  'The': 25720,
#  'tomato': 2136,
#  'flavor': 7690,
#  'this': 87057,
#  'freezer': 874,
#  'tag': 808,
#  'soup': 4437,
#  'froze': 645,
#  'beautifully.': 305,
#  'prepared': 935,
#  'as': 35493,
#  'directed': 720,
#  'then': 8440,
#  'allowed': 225,
#  'cool': 953,
#  'container.': 46,
#  'thawed': 211,
#  'fridge': 922,
#  'reheated': 222,
#  'stovetop.': 38,
#  'Worked': 251,
#  'perfectly!': 158,
#  'forgot': 1290,
#  'add': 12987,
#  'skim': 409,
#  'milk': 3759,
#  'still': 6693,
#  'tasted': 4119,
#  'pretty': 3499,
#  'good!': 3887,
#  'Dancer!': 17,
#  'dinner': 3882,
#  'excellent,': 186,
#  'finally': 513,
#  'found': 5067,
#  'tuna': 488,
#  'casserole': 798,
#  'we': 12841,
#  'enjoy,': 11,
#  'thanks.': 123,
#  'When': 1630,
#  'snapped': 9,
#  'picture,': 61,
#  'review': 1142,
#  'recipe.': 14337,
#  'toasted': 775,
#  'pecans': 624,
#  'dish,': 801,
#  'at': 15362,
#  'party': 1243,
#  'Prime': 23,
#  'Rib.': 4,
#  'Ten': 16,
#  'stars': 2070,
#  'Lennie': 29,
#  '!!': 334,
#  'good': 16106,
#  'combination': 1801,
#  'flavors': 2212,
#  'reduce': 910,
#  'rice': 3664,
#  'cilantro': 731,
#  'next': 10082,
#  'time,': 2236,
#  'thanks': 3197,
#  'sharing': 6196,
#  'hon!...Kitten': 9,
#  'Oh': 1335,
#  'Bergy!': 61,
#  'wonderful': 5681,
#  'cakes': 433,
#  'awesome.': 550,
#  'Fast': 83,
#  'put': 8578,
#  'together.': 1445,
#  'get': 6753,
#  'fish': 1128,
#  'where': 971,
#  'live': 435,
#  '(yuck).': 5,
#  'am': 6191,
#  'tired': 147,
#  'trying': 1847,
#  'new': 2765,
#  'recipes': 2819,
#  'help': 761,
#  'lack': 174,
#  'quality.': 62,
#  'But': 2588,
#  'recipe,': 5129,
#  'problem.': 194,
#  'did': 17358,
#  '3': 4472,
#  'cloves': 897,
#  'garlic,': 1029,
#  'seasoned': 776,
#  'bread': 5904,
#  'crumbs': 801,
#  'Smash': 3,
#  'Seasoning(318441).': 1,
#  'It': 19417,
#  'has': 4861,
#  'no': 5863,
#  'salt!\r\nI': 1,
#  'tartar': 77,
#  'sauce': 11425,
#  'go': 3691,
#  '(56860).\r\nThank': 1,
#  'great': 19166,
#  'recipe!': 8487,
#  'very': 25681,
#  'moist': 2457,
#  'cornbread,': 47,
#  'two': 4466,
#  'days': 723,
#  'later.': 237,
#  'less': 3180,
#  'sugar': 6608,
#  'honey,': 203,
#  'farm': 56,
#  'butter...and': 3,
#  'corn,': 222,
#  'about': 12811,
#  '2': 8237,
#  'ears.': 5,
#  'Served': 1974,
#  'ribs': 1203,
#  'grill,': 124,
#  "I've": 5561,
#  'been': 5786,
#  'making': 11030,
#  'past': 418,
#  'several': 1714,
#  'years.': 460,
#  "It's": 2848,
#  'always': 4167,
#  'extremely': 598,
#  'easy!': 923,
#  'posting!': 2469,
#  'generic': 30,
#  'sweetened': 239,
#  'condensed': 231,
#  'works': 748,
#  'well,': 782,
#  'tastes': 2271,
#  'costs': 17,
#  '(I': 2369,
#  'usually': 1911,
#  'Wal-Mart': 3,
#  'brand).': 9,
#  'Exceptional': 7,
#  'delicious': 5729,
#  'make.': 3027,
#  'really': 19400,
#  'liked': 5537,
#  'weekday': 69,
#  'leftover': 1716,
#  'rice.': 1105,
#  'looking': 3050,
#  'different': 3537,
#  'ways': 353,
#  'ground': 2468,
#  'beef.': 346,
#  'love': 9526,
#  'sandwich!!': 10,
#  'alot': 435,
#  'sooo': 594,
#  'Lite': 22,
#  'brown': 3475,
#  'mustard': 1082,
#  'horse': 4,
#  'relish': 159,
#  'some': 20753,
#  'olives': 582,
#  "on's.": 1,
#  'Next': 3485,
#  'time': 17502,
#  'balsamic': 482,
#  'dressing...it': 2,
#  'mind.': 76,
#  ':)': 5164,
#  'cbreezie': 1,
#  'make,': 1286,
#  'affordable': 26,
#  'addicting.': 29,
#  'Our': 363,
#  'household': 66,
#  'it.': 11935,
#  'Blessings': 7,
#  'chef': 292,
#  'sharing.': 2159,
#  'never': 4979,
#  'apple': 1442,
#  'orange': 1633,
#  'juice': 2765,
#  'makes': 3300,
#  'all': 15499,
#  'difference': 673,
#  'texture': 2318,
#  'bread.': 1207,
#  'wonderful!!\r\nThank': 2,
#  'You': 2286,
#  'were': 20716,
#  'delicious!': 3344,
#  'grated': 943,
#  'bit': 9946,
#  'cheddar': 1380,
#  'cheese': 8218,
#  'top': 4343,
#  '5': 4283,
#  'minutes': 5013,
#  'before': 6918,
#  'they': 16863,
#  'done,': 239,
#  'seasoning': 2026,
#  'perfect.': 2023,
#  'best': 4551,
#  'pizza': 955,
#  'dough': 2740,
#  'made!': 190,
#  'Other': 574,
#  'tried': 4438,
#  'machine': 480,
#  'way': 6708,
#  'too': 10530,
#  'sticky.': 81,
#  'Leaving': 11,
#  'msg': 19,
#  'fine.': 946,
#  'divide': 60,
#  'half,': 411,
#  'knead': 90,
#  'floured': 83,
#  'surface': 69,
#  'few': 4897,
#  'times,': 290,
#  'stretch': 74,
#  'cirle.': 1,
#  'like': 20171,
#  'bake': 1806,
#  'cast-iron': 19,
#  'skillet-': 1,
#  'brush': 161,
#  'pan': 3626,
#  'olive': 2058,
#  'oil': 3790,
#  'sprinkle': 635,
#  'corn': 2175,
#  'meal.': 1607,
#  'crust': 1662,
#  '7': 705,
#  '10-15': 75,
#  'lowest': 28,
#  'rack': 265,
#  'oven.': 1053,
#  'saw': 745,
#  'Giada': 8,
#  'Today': 106,
#  'show': 174,
#  'last': 4502,
#  'month': 270,
#  'wanted': 2687,
#  'compare': 104,
#  'family': 7201,
#  'being': 1855,
#  'Marsala': 25,
#  'dry': 2150,
#  'red,': 78,
#  'chicken/turkey': 3,
#  'sausage,': 225,
#  'cutting': 557,
#  'sausages': 113,
#  'finishing': 127,
#  'cooking': 4203,
#  'stove': 565,
#  'My': 14347,
#  'traditionally': 25,
#  'serves': 152,
#  'sausage': 1116,
#  'peppers': 1410,
#  'polenta...this': 1,
#  'compared': 122,
#  'well': 5166,
#  'probably': 2651,
#  'calories': 377,
#  'heats': 11,
#  'kitchen': 520,
#  'summertime!': 2,
#  'meatloaf,': 47,
#  'took': 3830,
#  'reviewers': 587,
#  'suggestion': 524,
#  'another': 4777,
#  'crock': 1034,
#  'pot': 1977,
#  'meatloaf': 395,
#  '(#99616)': 1,
#  'it,': 3813,
#  'sauce,': 1640,
#  'meatloaf.': 109,
#  'sweet': 4938,
#  'tangy': 290,
#  'wonder': 263,
#  'addition.': 273,
#  'again.': 7348,
#  'deliciously': 87,
#  'simple.': 292,
#  'can': 9513,
#  'literally': 148,
#  'thrown': 103,
#  'soups': 203,
#  'i': 7770,
#  'ever': 3856,
#  'had.': 886,
#  'uncomplicated': 6,
#  'taste.': 2042,
#  ',': 715,
#  'from': 12802,
#  'appealed': 20,
#  'me': 7274,
#  'simplicity': 162,
#  'quick': 4068,
#  'could': 6285,
#  'made.': 705,
#  'both': 2697,
#  'flavor.': 3912,
#  'anything': 1423,
#  'see': 2244,
#  'can;': 1,
#  'more': 16840,
#  'substance': 14,
#  'nothing': 718,
#  '(thankfully)': 3,
#  'rustic': 43,
#  'roasted': 1256,
#  'balance': 423,
#  'other': 7016,
#  'ingredients.': 1084,
#  'paul': 2,
#  'newman': 1,
#  'marinara': 109,
#  '1/3': 778,
#  'cup': 7164,
#  'let': 2910,
#  'simmer': 398,
#  'out.': 1223,
#  'would': 16597,
#  'definitly': 60,
#  'much': 12363,
#  'plus': 779,
#  'tea!': 45,
#  'aroma': 300,
#  'tea': 535,
#  'steeping': 10,
#  'five': 663,
#  'minutes,': 843,
#  'wonderful!': 1109,
#  'large': 2093,
#  'glass': 571,
#  'ice': 1500,
#  'enjoyed!': 69,
#  'Good': 1325,
#  'marinade.': 218,
#  'Jack': 169,
#  'Daniels': 23,
#  'exactly': 3583,
#  'except': 2033,
#  "didn't": 14046,
#  'marinate': 353,
#  'quite': 3819,
#  'long.': 221,
#  'hours.': 867,
#  'grilled': 1248,
#  'counter': 137,
#  'grill': 812,
#  'everyone': 2528,
#  'enjoyed': 6746,
#  'Even': 1366,
#  'DH,': 122,
#  'who': 3066,
#  "doesn't": 1810,
#  'beef': 2513,
#  'dressed': 64,
#  'up,': 513,
#  'said': 3122,
#  'Almost': 108,
#  'teriyaki': 96,
#  'baked': 4137,
#  'potato': 1754,
#  'asparagus.': 143,
#  'posting.': 2221,
#  'Fantastic': 361,
#  'earning': 2,
#  'raves': 111,
#  'table.': 201,
#  'Thanks,': 1331,
#  'homegirl!': 5,
#  'comforting.': 50,
#  'low-sodium,': 1,
#  'low-fat': 296,
#  'chicken': 11332,
#  'stock.': 166,
#  'butter.': 945,
#  'dried': 2248,
#  'parsley.': 200,
#  'do': 6861,
#  'than': 10333,
#  'an': 10553,
#  'hour,': 174,
#  'Me': 65,
#  'course.': 92,
#  'Breezermom': 3,
#  'Market': 162,
#  'game': 469,
#  'Easy': 1911,
#  'good.': 7001,
#  'Will': 3432,
#  'again': 7921,
#  'kids': 3123,
#  'weekend,': 54,
#  'your': 6415,
#  'cookies': 1935,
#  'already': 1564,
#  '(your': 4,
#  'Triple': 17,
#  'Chocolates).': 1,
#  "We're": 115,
#  'addicted': 63,
#  'jam': 430,
#  '--': 1634,
#  "it's": 4846,
#  'tend': 205,
#  'vinegar-phobic': 1,
#  'half;': 9,
#  'adore': 101,
#  'black': 1609,
#  'pepper,': 929,
#  'increase': 507,
#  'half.': 567,
#  'Also,': 1561,
#  'once': 1547,
#  'strawberries': 539,
#  'cook': 4212,
#  'down,': 140,
#  'masher': 37,
#  'break': 188,
#  'them': 19689,
#  'consistency.': 287,
#  'pepper': 4401,
#  'kick': 525,
#  'fun,': 59,
#  'English': 151,
#  'muffins,': 161,
#  'peanut': 1356,
#  'butter': 5572,
#  '&': 9664,
#  'jelly': 298,
#  'sandwiches': 473,
#  '(made': 53,
#  'wheat': 1778,
#  'bread.)': 3,
#  'wish': 831,
#  'canning': 142,
#  'store': 1248,
#  'shelf': 48,
#  'it!': 4313,
#  'started': 876,
#  'yesterday': 436,
#  'keep': 2162,
#  'up.': 1429,
#  'back': 3474,
#  'coffee': 976,
#  'figured': 251,
#  'might': 2834,
#  'along': 1572,
#  'benefits.': 12,
#  'OK,': 118,
#  'NEVER': 136,
#  'buy': 1174,
#  'jarred': 130,
#  'terrific!': 129,
#  'early': 259,
#  'day,': 352,
#  'later!': 31,
#  'pizza,': 66,
#  'freezer.': 284,
#  'cant': 183,
#  'wait.': 63,
#  'hint': 419,
#  'spice': 1363,
#  'red': 4424,
#  'omitted': 1607,
#  'flakes': 754,
#  'small': 3035,
#  'delicious.': 3734,
#  'again,': 2053,
#  'tenderness': 27,
#  'rub': 356,
#  'right.': 542,
#  'cold,': 101,
#  'yogurt': 961,
#  'whipped': 834,
#  'in,': 275,
#  'or': 12020,
#  'top.': 1375,
#  'cumin,': 184,
#  'curry,': 57,
#  'cinnamon': 2082,
#  'try': 8937,
#  'Chinese': 203,
#  '5.': 153,
#  "can't": 3022,
#  'resist': 98,
#  'splash': 304,
#  'too!': 1288,
#  '"bake"': 5,
#  'squash': 549,
#  'microwave': 830,
#  '8': 1712,
#  'minute': 545,
#  'blasts': 1,
#  'peel': 343,
#  'when': 9491,
#  'cool,': 89,
#  'freeze': 792,
#  'flesh.': 7,
#  'Carrots': 32,
#  'eaten': 749,
#  'right': 3563,
#  'highly': 529,
#  'recommend': 1542,
#  'these': 14418,
#  'delicious,': 1064,
#  'yet': 1087,
#  'treats!': 27,
#  'plastic': 293,
#  'popsicle': 9,
#  'molds': 10,
#  'store.': 239,
#  'halved': 1284,
#  '16': 340,
#  'popsicles.': 5,
#  'They': 5927,
#  'adults': 195,
#  'gone': 759,
#  'crazy': 379,
#  'eating': 2032,
#  'And': 2587,
#  'since': 4612,
#  "they're": 440,
#  'them!': 817,
#  'Barb': 33,
#  'become': 734,
#  'favorite!': 215,
#  'good,': 3031,
#  'modifications': 131,
#  '(and': 1001,
#  'laziness).': 1,
#  'semi': 81,
#  'breasts,': 185,
#  'browned': 670,
#  'them,': 1125,
#  'stock': 853,
#  'rest': 1884,
#  'through': 1258,
#  'simmer.': 28,
#  'omit': 595,
#  'avoid': 195,
#  'sugary-ness': 1,
#  'commented': 144,
#  'PERFECT.': 35,
#  'As': 1547,
#  'couscous': 179,
#  'anything,': 94,
#  'cold': 1240,
#  'broth': 1953,
#  'soak': 317,
#  'wait': 2103,
#  'breasts': 981,
#  'cook.': 325,
#  'margarine': 312,
#  'garlic-buttery': 1,
#  'certainly': 920,
#  'disappoint).': 1,
#  '#289161.': 1,
#  'Miraklegirl!': 4,
#  'fantastic!': 779,
#  'soft': 1275,
#  'chewy': 397,
#  'loveddd': 1,
#  'friends.': 197,
#  'chopped': 3127,
#  'mars': 2,
#  'bar': 219,
#  'chocolate': 4609,
#  'chips': 1692,
#  'worked': 3075,
#  'charm': 25,
#  'definitely': 6267,
#  'THANKS': 93,
#  'Christmas': 1344,
#  'party!': 71,
#  'Thank': 9735,
#  'treat!': 343,
#  'dressing': 2160,
#  'lot.': 369,
#  'sesame': 650,
#  'seeds': 805,
#  'lamb': 384,
#  'marinaded': 64,
#  'spices.': 376,
#  'posting': 4351,
#  'simply': 738,
#  'WONDERFUL!': 102,
#  'any': 6231,
#  'salt,': 1020,
#  'substitution': 119,
#  "necessity..didn't": 1,
#  'hash': 168,
#  'browns,': 19,
#  'potatoes.': 996,
#  'About': 72,
#  'half': 7891,
#  'peeked': 5,
#  'browning': 302,
#  'bottom': 1067,
#  'potatoes': 3793,
#  "weren't": 511,
#  'cooking.': 721,
#  'needed': 2633,
#  'water.': 897,
#  'DUH!': 1,
#  'remember': 574,
#  'how': 5263,
#  'added,': 81,
#  "I'll": 5414,
#  'redo': 7,
#  'browns': 104,
#  'die': 409,
#  'for....': 2,
#  'truly!': 1,
#  'good..': 25,
#  'it..': 61,
#  'give': 3294,
#  '3.5': 93,
#  'stars.': 688,
#  'okay': 242,
#  'again.<br/><br/>I': 2,
#  'drumsticks': 59,
#  'wings': 425,
#  'grocery': 438,
#  'low': 2407,
#  'sodium': 453,
#  'soy': 1154,
#  'sauce.': 3014,
#  'forget': 241,
#  'marinade': 1074,
#  'chicken.': 1191,
#  'know': 3493,
#  'affected': 64,
#  'thicker.': 86,
#  'barbecue': 199,
#  'move': 69,
#  'fluid.': 6,
#  'thicken': 702,
#  'starch': 190,
#  'flour.': 770,
#  'stated': 531,
#  ':-)': 651,
#  'breakfast!': 170,
#  'mom': 793,
#  'Northern': 39,
#  'Ireland': 14,
#  'introduced': 38,
#  'Marmite': 9,
#  'age': 38,
#  'rye': 150,
#  'marmite': 8,
#  'dip': 1014,
#  'eggs.': 408,
#  'you!': 1483,
#  "Paula's": 14,
#  'Peach': 20,
#  'Dump': 9,
#  'Cake': 198,
#  '#125391': 1,
#  '(only': 110,
#  '4)': 28,
#  'forward': 785,
#  'her': 1377,
#  'call': 572,
#  'future.': 285,
#  'hand': 1526,
#  'dessert': 1009,
#  "'fix'": 2,
#  'table': 454,
#  'short': 442,
#  'notice.': 16,
#  'Wow!': 684,
#  'What': 2588,
#  'amazing': 894,
#  'stuff!': 202,
#  'Hokey': 4,
#  'Pokey': 5,
#  'ice-cream,': 6,
#  'this.\nI': 3,
#  'shocked': 59,
#  'complete': 234,
#  'colour': 105,
#  'after': 5685,
#  'stirring': 211,
#  'baking': 3090,
#  'soda': 304,
#  'through.': 295,
#  'quick.\nI': 1,
#  'burned': 183,
#  'ours': 252,
#  'difficult': 371,
#  'spread': 1079,
#  'flat': 296,
#  'pan,': 648,
#  'first': 6060,
#  'go.\nNext': 1,
#  "what's": 98,
#  'come!': 37,
#  'manual': 7,
#  'method': 625,
#  'directions': 1514,
#  'follow': 830,
#  'produced': 149,
#  'results.': 577,
#  'light': 2557,
#  "za'atar": 11,
#  'topping.': 466,
#  'keeper!': 1322,
#  'Best': 634,
#  '2011': 181,
#  'event,': 33,
#  'recommended': 325,
#  'awalde': 7,
#  'sorry.': 81,
#  "wasn't": 2828,
#  'stretch.': 6,
#  'There': 1134,
#  'something': 3789,
#  'missing': 501,
#  'turn': 1174,
#  'amazing.': 614,
#  'turmeric': 68,
#  'strange': 126,
#  'color': 571,
#  'unappealing.': 7,
#  'smelled': 705,
#  'carne': 7,
#  'asada': 5,
#  'maybe': 2146,
#  'expecting.': 53,
#  'cooked': 6317,
#  'delightful': 259,
#  'while': 3129,
#  'grilling': 225,
#  'meet': 53,
#  'expectations': 42,
#  'served.': 66,
#  'watching': 228,
#  'think': 10740,
#  'tweak': 194,
#  'sure': 5334,
#  'is.': 636,
#  'Did': 453,
#  'Bergy!!': 10,
#  'microwaved': 176,
#  'spuds,': 5,
#  'onions,': 735,
#  'later': 496,
#  'night.': 694,
#  'onion': 3951,
#  'each': 2204,
#  'their': 1558,
#  'flavours': 430,
#  'come': 1545,
#  'distinctly.\r\nGood': 1,
#  'veggie': 655,
#  'dish.': 2670,
#  'Lovely!': 31,
#  'beautiful': 760,
#  'Thanksgiving': 638,
#  'morning.': 386,
#  'With': 666,
#  'link': 42,
#  'sliced': 2056,
#  'fruit': 1048,
#  'enjoy': 1321,
#  'visiting': 112,
#  'grands': 5,
#  'breakfast.': 477,
#  'Kittencal.': 81,
#  'teach': 25,
#  'high': 1257,
#  'school': 333,
#  'foods': 180,
#  'class': 97,
#  'studying': 8,
#  'legumes.': 2,
#  'topping': 1361,
#  'sour': 2563,
#  'cream,': 790,
#  'cheese,': 1367,
#  'Tobasco': 19,
#  'tortilla': 507,
#  'chips.': 630,
#  'While': 418,
#  'making,': 33,
#  'students': 37,
#  'look': 1527,
#  'Not': 1846,
#  'single': 364,
#  'student': 38,
#  '25': 458,
#  'disliked': 19,
#  'students.': 8,
#  'starting': 247,
#  'hour': 1180,
#  'period': 41,
#  'reheating': 45,
#  'day.': 1214,
#  'Many': 181,
#  'requested': 363,
#  'second': 1653,
#  'copy': 147,
#  'take': 2301,
#  'home!': 96,
#  'Great': 5595,
#  'job!': 33,
#  'definately': 1072,
#  'lemon': 3806,
#  'zest': 575,
#  'devine': 17,
#  'reheat': 135,
#  'oven': 3332,
#  ...}

# %% [markdown]
# Узкие места кода - итерирование, создание новых элементов

# %%
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# 312179   Excellent soup!  The tomato flavor is just gre...
# ...                                                    ...
# 1013457  This recipe was great! I made it last night. I...
# 158736   This recipe is outstanding. I followed the rec...
# 1059834  Well, we were not a crowd but it was a fabulou...
# 453285   I have been a steak eater and dedicated BBQ gr...
# 691207   Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 5 columns]

# %%
reviews.iloc[0].review.lower()
# Out:
# "last week whole sides of frozen salmon fillet was on sale in my local supermarket, so i bought tons (okay, only 3, but total weight was over 10 pounds).  this recipe is perfect for salmon fillet, even though it calls for salmon steaks.  i cut up the salmon into individual portions and followed the instructions exactly.  i'm on one of those food combining diets, so i left out the white wine but added just a dash of white wine vinegar instead (just a little bit, not enough to change the taste of the dish).  super yummy, and leftovers for lunch today (lucky me)!"

# %%
# %%time
def get_word_reviews_count_2(df):
    df['review'] = df['review'].fillna("")
    df['review'] = df['review'].apply(lambda x: ' '.join(set(x.split(' '))))
    return (pd.Series(' '.join(df.review).split()).value_counts())

get_word_reviews_count_2(reviews)
# Out:
# CPU times: total: 5.09 s
# Wall time: 5.19 s
# I                     101778
# and                    96186
# the                    92824
# a                      82412
# for                    74702
#                        ...
# (obviously)                1
# bowlful!                   1
# proportions/taste          1
# GOOOOD!!!!...Sorry         1
# 44th                       1
# Length: 164271, dtype: int64

# %% [markdown]
# 4. Напишите несколько версий функции `MAPE` (см. [MAPE](https://en.wikipedia.org/wiki/Mean_absolute_percentage_error)) для расчета среднего абсолютного процентного отклонения значения рейтинга отзыва на рецепт от среднего значения рейтинга по всем отзывам для этого рецепта.
#     1. Без использования векторизованных операций и методов массивов `numpy` и без использования `numba`
#     2. Без использования векторизованных операций и методов массивов `numpy`, но с использованием `numba`
#     3. С использованием векторизованных операций и методов массивов `numpy`, но без использования `numba`
#     4. C использованием векторизованных операций и методов массивов `numpy` и `numba`
#
# Измерьте время выполнения каждой из реализаций.
#
# Замечание: удалите из выборки отзывы с нулевым рейтингом.

# %%
reviews = reviews[reviews.rating !=0]
mean_rating = reviews.rating.mean()
mean_rating
# Out:
# 4.6611588859881055

# %%
# %%time
#A
def mape_A():
    n = reviews.shape[0]
    y = [abs(rating - mean_rating) for rating in reviews.rating]
    percentage_deviation = [(t / mean_rating) * 100 for t in y]
    mape = sum(percentage_deviation) / n
    return mape

mape_A()
# Out:
# CPU times: total: 62.5 ms
# Wall time: 64.8 ms
# 11.079150232255099

# %%
import numba

# %%
# %%time

@numba.jit(nopython=True)
def mape_B(reviews):
    n = len(reviews)
    mean_rating = sum(reviews) / n
    absolute_errors = []
    for rating in reviews:
        absolute_errors.append(abs(rating - mean_rating))
    percentage_errors = []
    for error in absolute_errors:
        percentage_errors.append(error / mean_rating)
    mape = sum(percentage_errors) * 100 / n
    return mape
mape_numba(list(reviews.rating.values))
# Out:
# C:\Users\maria\anaconda3\lib\site-packages\numba\core\ir_utils.py:2152: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected list' found for argument 'reviews' of function 'mape_numba'.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "<timed exec>", line 1:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# CPU times: total: 875 ms
# Wall time: 884 ms
# 11.079150232279916

# %%
# %%time
import numpy as np
def mape_C():
    n = reviews.shape[0]
    mean_rating = np.mean(reviews.rating)
    absolute_errors = np.abs(reviews.rating - mean_rating)
    percentage_errors = absolute_errors / mean_rating
    mape = np.sum(percentage_errors) * 100 / n
    return mape
mape_B()
# Out:
# CPU times: total: 0 ns
# Wall time: 14.2 ms
# 11.07915023226724

# %%
# %%time
import numpy as np
import numba

@numba.jit(nopython=True)
def mape_D(ratings_array):
    n = len(ratings_array)
    mean_rating = np.mean(ratings_array)
    absolute_errors = np.abs(ratings_array - mean_rating)
    percentage_errors = absolute_errors / mean_rating
    mape = np.sum(percentage_errors) * 100 / n
    return mape
mape_C(reviews.rating.values)
# Out:
# CPU times: total: 250 ms
# Wall time: 244 ms
# 11.079150232279916

# %% [markdown]
# #### [версия 2]
# * Уточнены формулировки задач 1, 3, 4
